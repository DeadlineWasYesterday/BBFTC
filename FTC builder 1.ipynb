# %%
##Load metadata from file

import ast

d = {}
nary = {}
with open("metadata_trial4.txt", 'r') as f:
    for line in f:
        d = (ast.literal_eval(line))
        nary.update({d['id'] : d})

# %%
#Filter terms that have children and aspect

filnary = {}
kilnary = {}
nochild = {}

for key, value in nary.items():
    if value.get('children') != None:
        filnary = ({'id' : value['id'], 'name' : value['name'], 'aspect' : value['aspect'], 
                    'children' : value['children']})
        kilnary.update({key : filnary})
    else:
        filnary = ({'id' : value['id'], 'name' : value['name'], 'aspect' : value['aspect']})
        nochild.update({key : filnary})

# %%
#remove anything that's not a biological process or molecular function from kilnary

keys = []
for key, value in kilnary.items():
    if value['aspect'] != 'biological_process' and value['aspect'] != 'molecular_function':
        keys.append(key)
        
for i in keys:
    del kilnary[i]

# %%
#get parents

for key, value in kilnary.items():
    for item in value['children']:
        if nary[item['id']].get('parent') == None:
            nary[item['id']]['parent'] = []
            nary[item['id']]['parent'].append({'id' : key, 'relation' : item['relation']})
        else:
            nary[item['id']]['parent'].append({'id' : key, 'relation' : item['relation']})
            
for key, value in nary.items():
    if value.get('parent') == None:
        value['parent'] = []

# %%
nary
# Out:
# {'GO:0000001': {'id': 'GO:0000001',
#   'isObsolete': False,
#   'name': 'mitochondrion inheritance',
#   'definition': {'text': 'The distribution of mitochondria, including the mitochondrial genome, into daughter cells after mitosis or meiosis, mediated by interactions between mitochondria and the cytoskeleton.',
#    'xrefs': [{'dbCode': 'PMID', 'dbId': '10873824'},
#     {'dbCode': 'PMID', 'dbId': '11389764'}]},
#   'synonyms': [{'name': 'mitochondrial inheritance', 'type': 'exact'}],
#   'aspect': 'biological_process',
#   'usage': 'Unrestricted',
#   'parent': [{'id': 'GO:0048308', 'relation': 'is_a'},
#    {'id': 'GO:0048311', 'relation': 'is_a'}]},
#  'GO:0000002': {'id': 'GO:0000002',
#   'isObsolete': False,
#   'name': 'mitochondrial genome maintenance',
#   'definition': {'text': 'The maintenance of the structure and integrity of the mitochondrial genome; includes replication and segregation of the mitochondrial chromosome.'},
#   'children': [{'id': 'GO:0033955', 'relation': 'is_a'},
#    {'id': 'GO:0032042', 'relation': 'part_of'}],
#   'aspect': 'biological_process',
#   'usage': 'Unrestricted',
#   'parent': [{'id': 'GO:0007005', 'relation': 'is_a'}]},
#  'GO:0000003': {'id': 'GO:0000003',
#   'isObsolete': False,
#   'name': 'reproduction',
#   'definition': {'text': 'The production of new individuals that contain some portion of genetic material inherited from one or more parent organisms.',
#    'xrefs': [{'dbCode': 'ISBN', 'dbId': '0198506732'}]},
#   'synonyms': [{'name': 'reproductive physiological process',
#     'type': 'exact'}],
#   'children': [{'id': 'GO:0032504', 'relation': 'is_a'},
#    {'id': 'GO:0003006', 'relation': 'part_of'},
#    {'id': 'GO:0019098', 'relation': 'part_of'},
#    {'id': 'GO:0019954', 'relation': 'is_a'},
#    {'id': 'GO:0061887', 'relation': 'is_a'},
#    {'id': 'GO:0019953', 'relation': 'is_a'},
#    {'id': 'GO:0032505', 'relation': 'is_a'},
#    {'id': 'GO:0022414', 'relation': 'part_of'}],
#   'aspect': 'biological_process',
#   'usage': 'Unrestricted',
#   'parent': [{'id': 'GO:0008150', 'relation': 'is_a'},
#    {'id': 'GO:0007582', 'relation': 'is_a'},
#    {'id': 'GO:0000004', 'relation': 'is_a'},
#    {'id': 'GO:0044699', 'relation': 'is_a'}]},
#  'GO:0000006': {'id': 'GO:0000006',
#   'isObsolete': False,
#   'name': 'high-affinity zinc transmembrane transporter activity',
#   'definition': {'text': 'Enables the transfer of zinc ions (Zn2+) from one side of a membrane to the other, probably powered by proton motive force. In high-affinity transport the transporter is able to bind the solute even if it is only present at very low concentrations.',
#    'xrefs': [{'dbCode': 'TC', 'dbId': '2.A.5.1.1'}]},
#   'synonyms': [{'name': 'high-affinity zinc uptake transmembrane transporter activity',
#     'type': 'related'},
#    {'name': 'high affinity zinc uptake transmembrane transporter activity',
#     'type': 'exact'}],
#   'aspect': 'molecular_function',
#   'usage': 'Unrestricted',
#   'parent': [{'id': 'GO:0005385', 'relation': 'is_a'}]},
#  'GO:0000007': {'id': 'GO:0000007',
#   'isObsolete': False,
#   'name': 'low-affinity zinc ion transmembrane transporter activity',
#   'definition': {'text': 'Enables the transfer of a solute or solutes from one side of a membrane to the other according to the reaction: Zn2+ = Zn2+, probably powered by proton motive force. In low-affinity transport the transporter is able to bind the solute only if it is present at very high concentrations.',
#    'xrefs': [{'dbCode': 'ISBN', 'dbId': '0815340729'}]},
#   'aspect': 'molecular_function',
#   'usage': 'Unrestricted',
#   'parent': [{'id': 'GO:0005385', 'relation': 'is_a'}]},
#  'GO:0000009': {'id': 'GO:0000009',
#   'isObsolete': False,
#   'name': 'alpha-1,6-mannosyltransferase activity',
#   'definition': {'text': 'Catalysis of the transfer of a mannose residue to an oligosaccharide, forming an alpha-(1->6) linkage.',
#    'xrefs': [{'dbCode': 'PMID', 'dbId': '2644248'}]},
#   'synonyms': [{'name': '1,6-alpha-mannosyltransferase activity',
#     'type': 'exact'}],
#   'children': [{'id': 'GO:0033164', 'relation': 'is_a'},
#    {'id': 'GO:0000136', 'relation': 'capable_of'},
#    {'id': 'GO:0052917', 'relation': 'is_a'},
#    {'id': 'GO:0052824', 'relation': 'is_a'}],
#   'aspect': 'molecular_function',
#   'usage': 'Unrestricted',
#   'parent': [{'id': 'GO:0000030', 'relation': 'is_a'}]},
#  'GO:0000010': {'id': 'GO:0000010',
#   'isObsolete': False,
#   'name': 'trans-hexaprenyltranstransferase activity',
#   'definition': {'text': 'Catalysis of the reaction: all-trans-hexaprenyl diphosphate + isopentenyl diphosphate = all-trans-heptaprenyl diphosphate + diphosphate.',
#    'xrefs': [{'dbCode': 'PMID', 'dbId': '9708911'}]},
#   'aspect': 'molecular_function',
#   'usage': 'Unrestricted',
#   'parent': [{'id': 'GO:0016765', 'relation': 'is_a'},
#    {'id': 'GO:0016766', 'relation': 'is_a'}]},
#  'GO:0000011': {'id': 'GO:0000011',
#   'isObsolete': False,
#   'name': 'vacuole inheritance',
#   'definition': {'text': 'The distribution of vacuoles into daughter cells after mitosis or meiosis, mediated by interactions between vacuoles and the cytoskeleton.',
#    'xrefs': [{'dbCode': 'PMID', 'dbId': '10873824'},
#     {'dbCode': 'PMID', 'dbId': '14616069'}]},
#   'aspect': 'biological_process',
#   'usage': 'Unrestricted',
#   'parent': [{'id': 'GO:0007033', 'relation': 'is_a'},
#    {'id': 'GO:0048308', 'relation': 'is_a'},
#    {'id': 'GO:0044086', 'relation': 'is_a'}]},
#  'GO:0000012': {'id': 'GO:0000012',
#   'isObsolete': False,
#   'name': 'single strand break repair',
#   'definition': {'text': 'The repair of single strand breaks in DNA. Repair of such breaks is mediated by the same enzyme systems as are used in base excision repair.',
#    'xrefs': [{'dbCode': 'URL',
#      'dbId': 'http://www.ultranet.com/~jkimball/BiologyPages/D/DNArepair.html'}]},
#   'children': [{'id': 'GO:1903516', 'relation': 'regulates'},
#    {'id': 'GO:1903517', 'relation': 'negatively_regulates'},
#    {'id': 'GO:1903518', 'relation': 'positively_regulates'},
#    {'id': 'GO:1990396', 'relation': 'is_a'},
#    {'id': 'GO:1903823', 'relation': 'is_a'}],
#   'aspect': 'biological_process',
#   'usage': 'Unrestricted',
#   'parent': [{'id': 'GO:0006281', 'relation': 'is_a'}]},
#  'GO:0000014': {'id': 'GO:0000014',
#   'isObsolete': False,
#   'name': 'single-stranded DNA endodeoxyribonuclease activity',
#   'definition': {'text': 'Catalysis of the hydrolysis of ester linkages within a single-stranded deoxyribonucleic acid molecule by creating internal breaks.'},
#   'synonyms': [{'name': 'single-stranded DNA specific endodeoxyribonuclease activity',
#     'type': 'related'},
#    {'name': 'ssDNA-specific endodeoxyribonuclease activity',
#     'type': 'related'}],
#   'children': [{'id': 'GO:1990599', 'relation': 'is_a'},
#    {'id': 'GO:1990601', 'relation': 'is_a'}],
#   'aspect': 'molecular_function',
#   'usage': 'Unrestricted',
#   'parent': [{'id': 'GO:0004520', 'relation': 'is_a'}]},
#  'GO:0000015': {'id': 'GO:0000015',
#   'isObsolete': False,
#   'name': 'phosphopyruvate hydratase complex',
#   'definition': {'text': 'A multimeric enzyme complex, usually a dimer or an octamer, that catalyzes the conversion of 2-phospho-D-glycerate to phosphoenolpyruvate and water.',
#    'xrefs': [{'dbCode': 'ISBN', 'dbId': '0198506732'}]},
#   'synonyms': [{'name': 'enolase complex', 'type': 'exact'}],
#   'aspect': 'cellular_component',
#   'usage': 'Unrestricted',
#   'parent': [{'id': 'GO:0004634', 'relation': 'capable_of'}]},
#  'GO:0000016': {'id': 'GO:0000016',
#   'isObsolete': False,
#   'name': 'lactase activity',
#   'definition': {'text': 'Catalysis of the reaction: lactose + H2O = D-glucose + D-galactose.',
#    'xrefs': [{'dbCode': 'PMID', 'dbId': '12023280'}]},
#   'synonyms': [{'name': 'lactose galactohydrolase activity', 'type': 'exact'},
#    {'name': 'lactase-phlorizin hydrolase activity', 'type': 'broad'}],
#   'aspect': 'molecular_function',
#   'usage': 'Unrestricted',
#   'parent': [{'id': 'GO:0004553', 'relation': 'is_a'},
#    {'id': 'GO:0016800', 'relation': 'is_a'}]},
#  'GO:0000017': {'id': 'GO:0000017',
#   'isObsolete': False,
#   'name': 'alpha-glucoside transport',
#   'definition': {'text': 'The directed movement of alpha-glucosides into, out of or within a cell, or between cells, by means of some agent such as a transporter or pore. Alpha-glucosides are glycosides in which the sugar group is a glucose residue, and the anomeric carbon of the bond is in an alpha configuration.',
#    'xrefs': [{'dbCode': 'ISBN', 'dbId': '0198506732'},
#     {'dbCode': 'URL', 'dbId': 'http://www.biochem.purdue.edu/'}]},
#   'children': [{'id': 'GO:0015151', 'relation': 'part_of'}],
#   'aspect': 'biological_process',
#   'usage': 'Unrestricted',
#   'parent': [{'id': 'GO:0042946', 'relation': 'is_a'}]},
#  'GO:0000018': {'id': 'GO:0000018',
#   'isObsolete': False,
#   'name': 'regulation of DNA recombination',
#   'definition': {'text': 'Any process that modulates the frequency, rate or extent of DNA recombination, a DNA metabolic process in which a new genotype is formed by reassortment of genes resulting in gene combinations different from those that were present in the parents.',
#    'xrefs': [{'dbCode': 'ISBN', 'dbId': '0198506732'}]},
#   'children': [{'id': 'GO:0000337', 'relation': 'is_a'},
#    {'id': 'GO:0060542', 'relation': 'is_a'},
#    {'id': 'GO:0010569', 'relation': 'is_a'},
#    {'id': 'GO:1903110', 'relation': 'is_a'},
#    {'id': 'GO:0061806', 'relation': 'is_a'},
#    {'id': 'GO:0045191', 'relation': 'is_a'},
#    {'id': 'GO:0010520', 'relation': 'is_a'},
#    {'id': 'GO:0000019', 'relation': 'is_a'},
#    {'id': 'GO:0045911', 'relation': 'is_a'},
#    {'id': 'GO:0045910', 'relation': 'is_a'},
#    {'id': 'GO:0072695', 'relation': 'is_a'}],
#   'aspect': 'biological_process',
#   'usage': 'Unrestricted',
#   'parent': [{'id': 'GO:0006310', 'relation': 'regulates'},
#    {'id': 'GO:0051052', 'relation': 'is_a'}]},
#  'GO:0000019': {'id': 'GO:0000019',
#   'isObsolete': False,
#   'name': 'regulation of mitotic recombination',
#   'definition': {'text': 'Any process that modulates the frequency, rate or extent of DNA recombination during mitosis.'},
#   'synonyms': [{'name': 'regulation of recombination within rDNA repeats',
#     'type': 'narrow'}],
#   'children': [{'id': 'GO:1903221', 'relation': 'is_a'},
#    {'id': 'GO:0045950', 'relation': 'is_a'},
#    {'id': 'GO:0032207', 'relation': 'is_a'},
#    {'id': 'GO:0045951', 'relation': 'is_a'}],
#   'aspect': 'biological_process',
#   'usage': 'Unrestricted',
#   'parent': [{'id': 'GO:0000018', 'relation': 'is_a'},
#    {'id': 'GO:0006312', 'relation': 'regulates'}]},
#  'GO:0000022': {'id': 'GO:0000022',
#   'isObsolete': False,
#   'name': 'mitotic spindle elongation',
#   'definition': {'text': 'The cell cycle process in which the distance is lengthened between poles of the mitotic spindle. Mitotic spindle elongation begins during mitotic prophase and ends during mitotic anaphase B.'},
#   'synonyms': [{'name': 'spindle elongation during mitosis', 'type': 'exact'}],
#   'children': [{'id': 'GO:1905121', 'relation': 'part_of'},
#    {'id': 'GO:0061804', 'relation': 'part_of'},
#    {'id': 'GO:0051256', 'relation': 'part_of'},
#    {'id': 'GO:0061805', 'relation': 'part_of'},
#    {'id': 'GO:1902845', 'relation': 'negatively_regulates'},
#    {'id': 'GO:1902846', 'relation': 'positively_regulates'},
#    {'id': 'GO:0032888', 'relation': 'regulates'}],
#   'aspect': 'biological_process',
#   'usage': 'Unrestricted',
#   'parent': [{'id': 'GO:0000070', 'relation': 'part_of'},
#    {'id': 'GO:0000278', 'relation': 'part_of'},
#    {'id': 'GO:0007052', 'relation': 'part_of'},
#    {'id': 'GO:0051231', 'relation': 'is_a'},
#    {'id': 'GO:1903047', 'relation': 'is_a'},
#    {'id': 'GO:0016359', 'relation': 'part_of'},
#    {'id': 'GO:0007067', 'relation': 'part_of'},
#    {'id': 'GO:0030472', 'relation': 'part_of'},
#    {'id': 'GO:0000071', 'relation': 'part_of'},
#    {'id': 'GO:0043148', 'relation': 'part_of'}]},
#  'GO:0000023': {'id': 'GO:0000023',
#   'isObsolete': False,
#   'name': 'maltose metabolic process',
#   'definition': {'text': 'The chemical reactions and pathways involving the disaccharide maltose (4-O-alpha-D-glucopyranosyl-D-glucopyranose), an intermediate in the catabolism of glycogen and starch.',
#    'xrefs': [{'dbCode': 'ISBN', 'dbId': '0198506732'}]},
#   'synonyms': [{'name': 'malt sugar metabolic process', 'type': 'exact'},
#    {'name': 'maltose metabolism', 'type': 'exact'},
#    {'name': 'malt sugar metabolism', 'type': 'exact'}],
#   'children': [{'id': 'GO:0000025', 'relation': 'is_a'},
#    {'id': 'GO:0032450', 'relation': 'part_of'},
#    {'id': 'GO:0000024', 'relation': 'is_a'}],
#   'aspect': 'biological_process',
#   'usage': 'Unrestricted',
#   'parent': [{'id': 'GO:0005984', 'relation': 'is_a'}]},
#  'GO:0000024': {'id': 'GO:0000024',
#   'isObsolete': False,
#   'name': 'maltose biosynthetic process',
#   'definition': {'text': 'The chemical reactions and pathways resulting in the formation of the disaccharide maltose (4-O-alpha-D-glucopyranosyl-D-glucopyranose).',
#    'xrefs': [{'dbCode': 'ISBN', 'dbId': '0198506732'}]},
#   'synonyms': [{'name': 'malt sugar biosynthetic process', 'type': 'exact'},
#    {'name': 'maltose synthesis', 'type': 'exact'},
#    {'name': 'malt sugar biosynthesis', 'type': 'exact'},
#    {'name': 'maltose anabolism', 'type': 'exact'},
#    {'name': 'maltose biosynthesis', 'type': 'exact'},
#    {'name': 'maltose formation', 'type': 'exact'}],
#   'aspect': 'biological_process',
#   'usage': 'Unrestricted',
#   'parent': [{'id': 'GO:0000023', 'relation': 'is_a'},
#    {'id': 'GO:0046351', 'relation': 'is_a'}]},
#  'GO:0000025': {'id': 'GO:0000025',
#   'isObsolete': False,
#   'name': 'maltose catabolic process',
#   'definition': {'text': 'The chemical reactions and pathways resulting in the breakdown of the disaccharide maltose (4-O-alpha-D-glucopyranosyl-D-glucopyranose).',
#    'xrefs': [{'dbCode': 'ISBN', 'dbId': '0198506732'}]},
#   'synonyms': [{'name': 'maltose degradation', 'type': 'exact'},
#    {'name': 'maltose hydrolysis', 'type': 'narrow'},
#    {'name': 'maltose breakdown', 'type': 'exact'},
#    {'name': 'malt sugar catabolism', 'type': 'exact'},
#    {'name': 'malt sugar catabolic process', 'type': 'exact'}],
#   'aspect': 'biological_process',
#   'usage': 'Unrestricted',
#   'parent': [{'id': 'GO:0000023', 'relation': 'is_a'},
#    {'id': 'GO:0046352', 'relation': 'is_a'}]},
#  'GO:0000026': {'id': 'GO:0000026',
#   'isObsolete': False,
#   'name': 'alpha-1,2-mannosyltransferase activity',
#   'definition': {'text': 'Catalysis of the transfer of a mannose residue to an oligosaccharide, forming an alpha-(1->2) linkage.',
#    'xrefs': [{'dbCode': 'PMID', 'dbId': '10521541'}]},
#   'children': [{'id': 'GO:0052918', 'relation': 'is_a'},
#    {'id': 'GO:0052926', 'relation': 'is_a'},
#    {'id': 'GO:0004377', 'relation': 'is_a'}],
#   'aspect': 'molecular_function',
#   'usage': 'Unrestricted',
#   'parent': [{'id': 'GO:0000030', 'relation': 'is_a'}]},
#  'GO:0000027': {'id': 'GO:0000027',
#   'isObsolete': False,
#   'name': 'ribosomal large subunit assembly',
#   'definition': {'text': 'The aggregation, arrangement and bonding together of constituent RNAs and proteins to form the large ribosomal subunit.'},
#   'synonyms': [{'name': '50S ribosomal subunit assembly', 'type': 'narrow'},
#    {'name': '60S ribosomal subunit assembly', 'type': 'narrow'}],
#   'children': [{'id': 'GO:1902775', 'relation': 'is_a'},
#    {'id': 'GO:0034463', 'relation': 'part_of'}],
#   'aspect': 'biological_process',
#   'usage': 'Unrestricted',
#   'parent': [{'id': 'GO:0022618', 'relation': 'is_a'},
#    {'id': 'GO:0042255', 'relation': 'part_of'},
#    {'id': 'GO:0042273', 'relation': 'part_of'},
#    {'id': 'GO:0042257', 'relation': 'part_of'}]},
#  'GO:0000028': {'id': 'GO:0000028',
#   'isObsolete': False,
#   'name': 'ribosomal small subunit assembly',
#   'definition': {'text': 'The aggregation, arrangement and bonding together of constituent RNAs and proteins to form the small ribosomal subunit.'},
#   'synonyms': [{'name': '30S ribosomal subunit assembly', 'type': 'narrow'},
#    {'name': '40S ribosomal subunit assembly', 'type': 'narrow'}],
#   'children': [{'id': 'GO:0034462', 'relation': 'part_of'},
#    {'id': 'GO:0034463', 'relation': 'part_of'}],
#   'aspect': 'biological_process',
#   'usage': 'Unrestricted',
#   'parent': [{'id': 'GO:0022618', 'relation': 'is_a'},
#    {'id': 'GO:0042255', 'relation': 'part_of'},
#    {'id': 'GO:0042274', 'relation': 'part_of'},
#    {'id': 'GO:0042257', 'relation': 'part_of'}]},
#  'GO:0000030': {'id': 'GO:0000030',
#   'isObsolete': False,
#   'name': 'mannosyltransferase activity',
#   'definition': {'text': 'Catalysis of the transfer of a mannosyl group to an acceptor molecule, typically another carbohydrate or a lipid.'},
#   'children': [{'id': 'GO:0000026', 'relation': 'is_a'},
#    {'id': 'GO:0000033', 'relation': 'is_a'},
#    {'id': 'GO:0016438', 'relation': 'is_a'},
#    {'id': 'GO:0004169', 'relation': 'is_a'},
#    {'id': 'GO:0000009', 'relation': 'is_a'},
#    {'id': 'GO:0047267', 'relation': 'is_a'},
#    {'id': 'GO:0031501', 'relation': 'capable_of'},
#    {'id': 'GO:0019187', 'relation': 'is_a'},
#    {'id': 'GO:0047252', 'relation': 'is_a'},
#    {'id': 'GO:0047264', 'relation': 'is_a'},
#    {'id': 'GO:0051751', 'relation': 'is_a'},
#    {'id': 'GO:0004376', 'relation': 'is_a'},
#    {'id': 'GO:0004582', 'relation': 'is_a'},
#    {'id': 'GO:0004584', 'relation': 'is_a'}],
#   'aspect': 'molecular_function',
#   'usage': 'Unrestricted',
#   'parent': [{'id': 'GO:0016758', 'relation': 'is_a'},
#    {'id': 'GO:0097502', 'relation': 'part_of'}]},
#  'GO:0000031': {'id': 'GO:0000031',
#   'isObsolete': False,
#   'name': 'mannosylphosphate transferase activity',
#   'definition': {'text': 'Catalysis of the transfer of a mannosylphosphate group from one compound to another.'},
#   'aspect': 'molecular_function',
#   'usage': 'Unrestricted',
#   'parent': [{'id': 'GO:0016740', 'relation': 'is_a'}]},
#  'GO:0000032': {'id': 'GO:0000032',
#   'isObsolete': False,
#   'name': 'cell wall mannoprotein biosynthetic process',
#   'definition': {'text': 'The chemical reactions and pathways resulting in the formation of cell wall mannoproteins, any cell wall protein that contains covalently bound mannose residues.'},
#   'synonyms': [{'name': 'cell wall mannoprotein anabolism', 'type': 'exact'},
#    {'name': 'cell wall mannoprotein biosynthesis', 'type': 'exact'},
#    {'name': 'cell wall mannoprotein formation', 'type': 'exact'},
#    {'name': 'cell wall mannoprotein synthesis', 'type': 'exact'}],
#   'aspect': 'biological_process',
#   'usage': 'Unrestricted',
#   'parent': [{'id': 'GO:0006057', 'relation': 'is_a'},
#    {'id': 'GO:0031506', 'relation': 'is_a'}]},
#  'GO:0000033': {'id': 'GO:0000033',
#   'isObsolete': False,
#   'name': 'alpha-1,3-mannosyltransferase activity',
#   'definition': {'text': 'Catalysis of the transfer of a mannose residue to an oligosaccharide, forming an alpha-(1->3) linkage.',
#    'xrefs': [{'dbCode': 'PMID', 'dbId': '10521541'}]},
#   'children': [{'id': 'GO:0052925', 'relation': 'is_a'}],
#   'aspect': 'molecular_function',
#   'usage': 'Unrestricted',
#   'parent': [{'id': 'GO:0000030', 'relation': 'is_a'}]},
#  'GO:0000034': {'id': 'GO:0000034',
#   'isObsolete': False,
#   'name': 'adenine deaminase activity',
#   'definition': {'text': 'Catalysis of the reaction: adenine + H2O = hypoxanthine + NH3.',
#    'xrefs': [{'dbCode': 'EC', 'dbId': '3.5.4.2'}]},
#   'synonyms': [{'name': 'adenine aminase activity', 'type': 'exact'},
#    {'name': 'adenase activity', 'type': 'exact'},
#    {'name': 'adenine aminohydrolase activity', 'type': 'exact'},
#    {'name': 'ADase activity', 'type': 'exact'}],
#   'aspect': 'molecular_function',
#   'usage': 'Unrestricted',
#   'parent': [{'id': 'GO:0016814', 'relation': 'is_a'},
#    {'id': 'GO:0019239', 'relation': 'is_a'}]},
#  'GO:0000035': {'id': 'GO:0000035',
#   'isObsolete': False,
#   'name': 'acyl binding',
#   'definition': {'text': 'Interacting selectively and non-covalently with an acyl group, any group formally derived by removal of the hydroxyl group from the acid function of a carboxylic acid.',
#    'xrefs': [{'dbCode': 'ISBN', 'dbId': '0198506732'}]},
#   'synonyms': [{'name': 'acyl-CoA or acyl binding', 'type': 'broad'}],
#   'aspect': 'molecular_function',
#   'usage': 'Unrestricted',
#   'parent': [{'id': 'GO:0005488', 'relation': 'is_a'}]},
#  'GO:0000036': {'id': 'GO:0000036',
#   'isObsolete': False,
#   'name': 'acyl carrier activity',
#   'definition': {'text': 'Binding an acyl group and presenting it for processing or offloading to a cognate enzyme. Covalently binds the acyl group via a phosphopantetheine prosthetic group and mediates protein-protein interactions with the enzyme conferring specificity. The acyl carrier protein (ACP) presents substrates to enzymes involved in fatty acid biosynthesis or in polyketide secondary metabolite biosynthesis.',
#    'xrefs': [{'dbCode': 'CHEBI', 'dbId': '22221'}]},
#   'synonyms': [{'name': 'ACP phosphopantetheine attachment site binding involved in fatty acid biosynthetic process',
#     'type': 'exact'}],
#   'children': [{'id': 'GO:0036370', 'relation': 'is_a'},
#    {'id': 'GO:1904091', 'relation': 'is_a'}],
#   'aspect': 'molecular_function',
#   'usage': 'Unrestricted',
#   'parent': [{'id': 'GO:0006633', 'relation': 'part_of'},
#    {'id': 'GO:0044620', 'relation': 'is_a'},
#    {'id': 'GO:0140104', 'relation': 'is_a'},
#    {'id': 'GO:0000037', 'relation': 'part_of'}]},
#  'GO:0000038': {'id': 'GO:0000038',
#   'isObsolete': False,
#   'name': 'very long-chain fatty acid metabolic process',
#   'definition': {'text': 'The chemical reactions and pathways involving a fatty acid which has a chain length greater than C22.',
#    'xrefs': [{'dbCode': 'CHEBI', 'dbId': '27283'}]},
#   'synonyms': [{'name': 'very long chain fatty acid metabolic process',
#     'type': 'exact'},
#    {'name': 'very-long-chain fatty acid metabolic process', 'type': 'exact'},
#    {'name': 'very-long-chain fatty acid metabolism', 'type': 'exact'}],
#   'children': [{'id': 'GO:0042761', 'relation': 'is_a'},
#    {'id': 'GO:0042760', 'relation': 'is_a'}],
#   'aspect': 'biological_process',
#   'usage': 'Unrestricted',
#   'parent': [{'id': 'GO:0006631', 'relation': 'is_a'}]},
#  'GO:0000041': {'id': 'GO:0000041',
#   'isObsolete': False,
#   'name': 'transition metal ion transport',
#   'definition': {'text': 'The directed movement of transition metal ions into, out of or within a cell, or between cells, by means of some agent such as a transporter or pore. A transition metal is an element whose atom has an incomplete d-subshell of extranuclear electrons, or which gives rise to a cation or cations with an incomplete d-subshell. Transition metals often have more than one valency state. Biologically relevant transition metals include vanadium, manganese, iron, copper, cobalt, nickel, molybdenum and silver.',
#    'xrefs': [{'dbCode': 'ISBN', 'dbId': '0198506732'}]},
#   'synonyms': [{'name': 'transition metal transport', 'type': 'exact'}],
#   'children': [{'id': 'GO:0015691', 'relation': 'is_a'},
#    {'id': 'GO:0006825', 'relation': 'is_a'},
#    {'id': 'GO:0015694', 'relation': 'is_a'},
#    {'id': 'GO:0036249', 'relation': 'is_a'},
#    {'id': 'GO:0006826', 'relation': 'is_a'},
#    {'id': 'GO:0015673', 'relation': 'is_a'},
#    {'id': 'GO:0006824', 'relation': 'is_a'},
#    {'id': 'GO:0015675', 'relation': 'is_a'},
#    {'id': 'GO:0006829', 'relation': 'is_a'},
#    {'id': 'GO:0006828', 'relation': 'is_a'},
#    {'id': 'GO:0015676', 'relation': 'is_a'},
#    {'id': 'GO:0046915', 'relation': 'part_of'}],
#   'aspect': 'biological_process',
#   'usage': 'Unrestricted',
#   'parent': [{'id': 'GO:0030001', 'relation': 'is_a'}]},
#  'GO:0000045': {'id': 'GO:0000045',
#   'isObsolete': False,
#   'name': 'autophagosome assembly',
#   'definition': {'text': 'The formation of a double membrane-bounded structure, the autophagosome, that occurs when a specialized membrane sac, called the isolation membrane, starts to enclose a portion of the cytoplasm.',
#    'xrefs': [{'dbCode': 'PMID', 'dbId': '9412464'}]},
#   'synonyms': [{'name': 'PAS formation', 'type': 'narrow'},
#    {'name': 'autophagic vacuole formation', 'type': 'related'},
#    {'name': 'autophagosome formation', 'type': 'exact'},
#    {'name': 'autophagosome biosynthesis', 'type': 'exact'},
#    {'name': 'autophagic vacuole assembly', 'type': 'exact'}],
#   'children': [{'id': 'GO:0061736', 'relation': 'part_of'},
#    {'id': 'GO:0061753', 'relation': 'part_of'},
#    {'id': 'GO:2000786', 'relation': 'positively_regulates'},
#    {'id': 'GO:0061908', 'relation': 'capable_of_part_of'},
#    {'id': 'GO:0061739', 'relation': 'part_of'},
#    {'id': 'GO:0034274', 'relation': 'capable_of_part_of'},
#    {'id': 'GO:0034497', 'relation': 'part_of'},
#    {'id': 'GO:1990316', 'relation': 'capable_of_part_of'},
#    {'id': 'GO:0062079', 'relation': 'capable_of_part_of'},
#    {'id': 'GO:1902902', 'relation': 'negatively_regulates'},
#    {'id': 'GO:0035032', 'relation': 'capable_of_part_of'},
#    {'id': 'GO:1990462', 'relation': 'capable_of_part_of'},
#    {'id': 'GO:0000407', 'relation': 'capable_of_part_of'},
#    {'id': 'GO:2000785', 'relation': 'regulates'}],
#   'aspect': 'biological_process',
#   'usage': 'Unrestricted',
#   'parent': [{'id': 'GO:0070925', 'relation': 'is_a'},
#    {'id': 'GO:1905037', 'relation': 'is_a'}]},
#  'GO:0000048': {'id': 'GO:0000048',
#   'isObsolete': False,
#   'name': 'peptidyltransferase activity',
#   'definition': {'text': 'Catalysis of the reaction: peptidyl-tRNA(1) + aminoacyl-tRNA(2) = tRNA(1) + peptidylaminoacyl-tRNA(2).',
#    'xrefs': [{'dbCode': 'EC', 'dbId': '2.3.2.12'},
#     {'dbCode': 'PMID', 'dbId': '11433365'},
#     {'dbCode': 'PMID', 'dbId': '9242921'}]},
#   'synonyms': [{'name': 'peptidyl-tRNA:aminoacyl-tRNA N-peptidyltransferase activity',
#     'type': 'exact'}],
#   'aspect': 'molecular_function',
#   'usage': 'Unrestricted',
#   'parent': [{'id': 'GO:0006412', 'relation': 'part_of'},
#    {'id': 'GO:0016755', 'relation': 'is_a'},
#    {'id': 'GO:0006453', 'relation': 'part_of'},
#    {'id': 'GO:0006416', 'relation': 'part_of'},
#    {'id': 'GO:0043037', 'relation': 'part_of'}]},
#  'GO:0000049': {'id': 'GO:0000049',
#   'isObsolete': False,
#   'name': 'tRNA binding',
#   'definition': {'text': 'Interacting selectively and non-covalently with transfer RNA.'},
#   'synonyms': [{'name': 'base pairing with tRNA', 'type': 'narrow'}],
#   'children': [{'id': 'GO:0030557', 'relation': 'is_a'},
#    {'id': 'GO:1990856', 'relation': 'is_a'}],
#   'aspect': 'molecular_function',
#   'usage': 'Unrestricted',
#   'parent': [{'id': 'GO:0003723', 'relation': 'is_a'},
#    {'id': 'GO:0000498', 'relation': 'is_a'},
#    {'id': 'GO:0044822', 'relation': 'is_a'}]},
#  'GO:0000050': {'id': 'GO:0000050',
#   'isObsolete': False,
#   'name': 'urea cycle',
#   'definition': {'text': 'The sequence of reactions by which arginine is synthesized from ornithine, then cleaved to yield urea and regenerate ornithine. The overall reaction equation is NH3 + CO2 + aspartate + 3 ATP + 2 H2O = urea + fumarate + 2 ADP + 2 phosphate + AMP + diphosphate.',
#    'xrefs': [{'dbCode': 'ISBN', 'dbId': '0198506732'}]},
#   'synonyms': [{'name': 'urea biosynthetic process', 'type': 'exact'},
#    {'name': 'ornithine cycle', 'type': 'exact'},
#    {'name': 'urea biosynthesis', 'type': 'exact'}],
#   'aspect': 'biological_process',
#   'usage': 'Unrestricted',
#   'parent': [{'id': 'GO:0019627', 'relation': 'is_a'},
#    {'id': 'GO:0043604', 'relation': 'is_a'},
#    {'id': 'GO:1901566', 'relation': 'is_a'}]},
#  'GO:0000052': {'id': 'GO:0000052',
#   'isObsolete': False,
#   'name': 'citrulline metabolic process',
#   'definition': {'text': 'The chemical reactions and pathways involving citrulline, N5-carbamoyl-L-ornithine, an alpha amino acid not found in proteins.',
#    'xrefs': [{'dbCode': 'ISBN', 'dbId': '0198506732'}]},
#   'synonyms': [{'name': 'citrulline metabolism', 'type': 'exact'}],
#   'children': [{'id': 'GO:0019240', 'relation': 'is_a'},
#    {'id': 'GO:0019241', 'relation': 'is_a'}],
#   'aspect': 'biological_process',
#   'usage': 'Unrestricted',
#   'parent': [{'id': 'GO:1901605', 'relation': 'is_a'}]},
#  'GO:0000053': {'id': 'GO:0000053',
#   'isObsolete': False,
#   'name': 'argininosuccinate metabolic process',
#   'definition': {'text': 'The chemical reactions and pathways involving argininosuccinate, 2-(N(omega)-arginino)succinate, an intermediate in the ornithine-urea cycle, where it is synthesized from citrulline and aspartate.',
#    'xrefs': [{'dbCode': 'ISBN', 'dbId': '0198506732'}]},
#   'synonyms': [{'name': 'argininosuccinate metabolism', 'type': 'exact'}],
#   'aspect': 'biological_process',
#   'usage': 'Unrestricted',
#   'parent': [{'id': 'GO:0006575', 'relation': 'is_a'},
#    {'id': 'GO:0072350', 'relation': 'is_a'},
#    {'id': 'GO:1901605', 'relation': 'is_a'}]},
#  'GO:0000054': {'id': 'GO:0000054',
#   'isObsolete': False,
#   'name': 'ribosomal subunit export from nucleus',
#   'definition': {'text': 'The directed movement of a ribosomal subunit from the nucleus into the cytoplasm.'},
#   'synonyms': [{'name': 'ribosomal subunit export from cell nucleus',
#     'type': 'exact'},
#    {'name': 'ribosomal subunit transport from nucleus to cytoplasm',
#     'type': 'exact'},
#    {'name': 'ribosomal subunit-nucleus export', 'type': 'exact'},
#    {'name': 'ribosome export from nucleus', 'type': 'related'},
#    {'name': 'ribosomal subunit export out of nucleus', 'type': 'exact'}],
#   'children': [{'id': 'GO:2000201', 'relation': 'negatively_regulates'},
#    {'id': 'GO:0000056', 'relation': 'is_a'},
#    {'id': 'GO:0000055', 'relation': 'is_a'},
#    {'id': 'GO:2000200', 'relation': 'regulates'},
#    {'id': 'GO:2000202', 'relation': 'positively_regulates'}],
#   'aspect': 'biological_process',
#   'usage': 'Unrestricted',
#   'parent': [{'id': 'GO:0033750', 'relation': 'is_a'},
#    {'id': 'GO:0042254', 'relation': 'part_of'},
#    {'id': 'GO:0051656', 'relation': 'is_a'},
#    {'id': 'GO:0071428', 'relation': 'is_a'},
#    {'id': 'GO:0033753', 'relation': 'is_a'},
#    {'id': 'GO:0007046', 'relation': 'part_of'}]},
#  'GO:0000055': {'id': 'GO:0000055',
#   'isObsolete': False,
#   'name': 'ribosomal large subunit export from nucleus',
#   'definition': {'text': 'The directed movement of a ribosomal large subunit from the nucleus into the cytoplasm.'},
#   'synonyms': [{'name': 'ribosomal large subunit transport from nucleus to cytoplasm',
#     'type': 'exact'},
#    {'name': 'ribosomal large subunit-nucleus export', 'type': 'exact'},
#    {'name': 'ribosomal large subunit export from cell nucleus',
#     'type': 'exact'},
#    {'name': '60S ribosomal subunit export from nucleus', 'type': 'narrow'},
#    {'name': 'ribosomal large subunit export out of nucleus', 'type': 'exact'},
#    {'name': '50S ribosomal subunit export from nucleus', 'type': 'narrow'}],
#   'children': [{'id': 'GO:2000205', 'relation': 'positively_regulates'},
#    {'id': 'GO:2000203', 'relation': 'regulates'},
#    {'id': 'GO:2000204', 'relation': 'negatively_regulates'}],
#   'aspect': 'biological_process',
#   'usage': 'Unrestricted',
#   'parent': [{'id': 'GO:0000054', 'relation': 'is_a'}]},
#  'GO:0000056': {'id': 'GO:0000056',
#   'isObsolete': False,
#   'name': 'ribosomal small subunit export from nucleus',
#   'definition': {'text': 'The directed movement of a ribosomal small subunit from the nucleus into the cytoplasm.'},
#   'synonyms': [{'name': '40S ribosomal subunit export from nucleus',
#     'type': 'narrow'},
#    {'name': 'ribosomal small subunit-nucleus export', 'type': 'exact'},
#    {'name': 'ribosomal small subunit transport from nucleus to cytoplasm',
#     'type': 'exact'},
#    {'name': 'ribosomal small subunit export from cell nucleus',
#     'type': 'exact'},
#    {'name': 'ribosomal small subunit export out of nucleus', 'type': 'exact'},
#    {'name': '30S ribosomal subunit export from nucleus', 'type': 'narrow'}],
#   'children': [{'id': 'GO:2000206', 'relation': 'regulates'},
#    {'id': 'GO:2000207', 'relation': 'negatively_regulates'},
#    {'id': 'GO:2000208', 'relation': 'positively_regulates'}],
#   'aspect': 'biological_process',
#   'usage': 'Unrestricted',
#   'parent': [{'id': 'GO:0000054', 'relation': 'is_a'}]},
#  'GO:0000062': {'id': 'GO:0000062',
#   'isObsolete': False,
#   'name': 'fatty-acyl-CoA binding',
#   'definition': {'text': 'Interacting selectively and non-covalently with acyl-CoA, any derivative of coenzyme A in which the sulfhydryl group is in thiolester linkage with a fatty acyl group.',
#    'xrefs': [{'dbCode': 'ISBN', 'dbId': '0198506732'}]},
#   'synonyms': [{'name': 'acyl-CoA or acyl binding', 'type': 'broad'}],
#   'children': [{'id': 'GO:0036042', 'relation': 'is_a'}],
#   'aspect': 'molecular_function',
#   'usage': 'Unrestricted',
#   'parent': [{'id': 'GO:0032559', 'relation': 'is_a'},
#    {'id': 'GO:0033218', 'relation': 'is_a'},
#    {'id': 'GO:0043168', 'relation': 'is_a'},
#    {'id': 'GO:0050662', 'relation': 'is_a'},
#    {'id': 'GO:1901567', 'relation': 'is_a'},
#    {'id': 'GO:1901681', 'relation': 'is_a'}]},
#  'GO:0000064': {'id': 'GO:0000064',
#   'isObsolete': False,
#   'name': 'L-ornithine transmembrane transporter activity',
#   'definition': {'text': 'Enables the transfer of L-ornithine from one side of a membrane to the other. L-ornithine is 2,5-diaminopentanoic acid.',
#    'xrefs': [{'dbCode': 'ISBN', 'dbId': '0815340729'}]},
#   'synonyms': [{'name': 'histidine/arginine/lysine/ornithine porter activity',
#     'type': 'related'},
#    {'name': 'L-ornithine transporter activity', 'type': 'broad'}],
#   'children': [{'id': 'GO:0015496', 'relation': 'is_a'},
#    {'id': 'GO:0097627', 'relation': 'is_a'}],
#   'aspect': 'molecular_function',
#   'usage': 'Unrestricted',
#   'parent': [{'id': 'GO:0008324', 'relation': 'is_a'},
#    {'id': 'GO:0015179', 'relation': 'is_a'},
#    {'id': 'GO:1903352', 'relation': 'part_of'}]},
#  'GO:0000070': {'id': 'GO:0000070',
#   'isObsolete': False,
#   'name': 'mitotic sister chromatid segregation',
#   'definition': {'text': 'The cell cycle process in which replicated homologous chromosomes are organized and then physically separated and apportioned to two sets during the mitotic cell cycle. Each replicated chromosome, composed of two sister chromatids, aligns at the cell equator, paired with its homologous partner. One homolog of each morphologic type goes into each of the resulting chromosome sets.'},
#   'synonyms': [{'name': 'mitotic chromosome segregation', 'type': 'exact'},
#    {'name': 'mitotic sister-chromatid adhesion release', 'type': 'narrow'}],
#   'children': [{'id': 'GO:0007080', 'relation': 'part_of'},
#    {'id': 'GO:0033047', 'relation': 'regulates'},
#    {'id': 'GO:0000022', 'relation': 'part_of'},
#    {'id': 'GO:0062033', 'relation': 'positively_regulates'},
#    {'id': 'GO:0007076', 'relation': 'part_of'},
#    {'id': 'GO:0007079', 'relation': 'part_of'},
#    {'id': 'GO:0007064', 'relation': 'part_of'},
#    {'id': 'GO:0007083', 'relation': 'part_of'},
#    {'id': 'GO:0051306', 'relation': 'part_of'},
#    {'id': 'GO:0033048', 'relation': 'negatively_regulates'}],
#   'aspect': 'biological_process',
#   'usage': 'Unrestricted',
#   'parent': [{'id': 'GO:0000819', 'relation': 'is_a'},
#    {'id': 'GO:0140014', 'relation': 'part_of'},
#    {'id': 'GO:1903047', 'relation': 'is_a'}]},
#  'GO:0000073': {'id': 'GO:0000073',
#   'isObsolete': False,
#   'name': 'initial mitotic spindle pole body separation',
#   'definition': {'text': 'The release of duplicated mitotic spindle pole bodies (SPBs) that begins with the nucleation of microtubules from each SPB within the nucleus, leading to V-shaped spindle microtubules. Interpolar microtubules that elongate from each pole are interconnected, forming overlapping microtubules. Capturing and antiparallel sliding apart of microtubules promotes the initial separation of the SPB.'},
#   'children': [{'id': 'GO:0010695', 'relation': 'regulates'},
#    {'id': 'GO:0010697', 'relation': 'negatively_regulates'},
#    {'id': 'GO:0010696', 'relation': 'positively_regulates'}],
#   'aspect': 'biological_process',
#   'usage': 'Unrestricted',
#   'parent': [{'id': 'GO:0061804', 'relation': 'part_of'},
#    {'id': 'GO:0110100', 'relation': 'is_a'},
#    {'id': 'GO:1903047', 'relation': 'is_a'},
#    {'id': 'GO:1905047', 'relation': 'part_of'}]},
#  'GO:0000075': {'id': 'GO:0000075',
#   'isObsolete': False,
#   'name': 'cell cycle checkpoint',
#   'definition': {'text': 'A cell cycle process that controls cell cycle progression by monitoring the integrity of specific cell cycle events. A cell cycle checkpoint begins with detection of deficiencies or defects and ends with signal transduction.'},
#   'comment': 'This term should not be used in direct manual annotation as it should always be possible to minimally designate mitotic or meiotic checkpoint, and usually to additionally specify the checkpoint (i.e mitotic spindle assembly checkpoint, mitotic DNA damage checkpoint etc). Note also that the effector processes are not part of the checkpoint but are positively regulated by the checkpoint signaling and should not be annotated here.',
#   'synonyms': [{'name': 'G2/M transition checkpoint', 'type': 'narrow'},
#    {'name': 'G1/S checkpoint', 'type': 'narrow'},
#    {'name': 'G1/S transition checkpoint', 'type': 'narrow'},
#    {'name': 'G2/M checkpoint', 'type': 'narrow'}],
#   'children': [{'id': 'GO:0031570', 'relation': 'is_a'},
#    {'id': 'GO:1901977', 'relation': 'negatively_regulates'},
#    {'id': 'GO:0072394', 'relation': 'part_of'},
#    {'id': 'GO:0072395', 'relation': 'part_of'},
#    {'id': 'GO:1901978', 'relation': 'positively_regulates'},
#    {'id': 'GO:0033313', 'relation': 'is_a'},
#    {'id': 'GO:0031577', 'relation': 'is_a'},
#    {'id': 'GO:0007093', 'relation': 'is_a'},
#    {'id': 'GO:1901976', 'relation': 'regulates'}],
#   'aspect': 'biological_process',
#   'usage': 'Electronic',
#   'parent': [{'id': 'GO:0009987', 'relation': 'is_a'},
#    {'id': 'GO:0045786', 'relation': 'is_a'},
#    {'id': 'GO:0050875', 'relation': 'is_a'},
#    {'id': 'GO:0044763', 'relation': 'is_a'},
#    {'id': 'GO:0008151', 'relation': 'is_a'}]},
#  'GO:0000076': {'id': 'GO:0000076',
#   'isObsolete': False,
#   'name': 'DNA replication checkpoint',
#   'definition': {'text': 'A cell cycle checkpoint that prevents the initiation of nuclear division until DNA replication is complete, thereby ensuring that progeny inherit a full complement of the genome.',
#    'xrefs': [{'dbCode': 'PMID', 'dbId': '11728327'},
#     {'dbCode': 'PMID', 'dbId': '12537518'}]},
#   'children': [{'id': 'GO:0072436', 'relation': 'part_of'},
#    {'id': 'GO:0072437', 'relation': 'part_of'},
#    {'id': 'GO:0033315', 'relation': 'is_a'},
#    {'id': 'GO:0033314', 'relation': 'is_a'}],
#   'aspect': 'biological_process',
#   'usage': 'Unrestricted',
#   'parent': [{'id': 'GO:0031570', 'relation': 'is_a'}]},
#  'GO:0000077': {'id': 'GO:0000077',
#   'isObsolete': False,
#   'name': 'DNA damage checkpoint',
#   'definition': {'text': 'A cell cycle checkpoint that regulates progression through the cell cycle in response to DNA damage. A DNA damage checkpoint may blocks cell cycle progression (in G1, G2 or metaphase) or slow the rate at which S phase proceeds.'},
#   'synonyms': [{'name': 'DNA damage response, signal transduction resulting in cell cycle arrest',
#     'type': 'narrow'}],
#   'children': [{'id': 'GO:2000001', 'relation': 'regulates'},
#    {'id': 'GO:2000002', 'relation': 'negatively_regulates'},
#    {'id': 'GO:0031572', 'relation': 'is_a'},
#    {'id': 'GO:0072421', 'relation': 'part_of'},
#    {'id': 'GO:0044773', 'relation': 'is_a'},
#    {'id': 'GO:0044783', 'relation': 'is_a'},
#    {'id': 'GO:0072422', 'relation': 'part_of'},
#    {'id': 'GO:2000003', 'relation': 'positively_regulates'}],
#   'aspect': 'biological_process',
#   'usage': 'Unrestricted',
#   'parent': [{'id': 'GO:0006974', 'relation': 'is_a'},
#    {'id': 'GO:0031570', 'relation': 'is_a'},
#    {'id': 'GO:0034984', 'relation': 'is_a'}]},
#  'GO:0000079': {'id': 'GO:0000079',
#   'isObsolete': False,
#   'name': 'regulation of cyclin-dependent protein serine/threonine kinase activity',
#   'definition': {'text': 'Any process that modulates the frequency, rate or extent of cyclin-dependent protein serine/threonine kinase activity.'},
#   'synonyms': [{'name': 'regulation of CDK activity', 'type': 'exact'},
#    {'name': 'regulation of cyclin-dependent protein kinase activity',
#     'type': 'broad'}],
#   'children': [{'id': 'GO:0019907', 'relation': 'capable_of_part_of'},
#    {'id': 'GO:0031660', 'relation': 'is_a'},
#    {'id': 'GO:0045736', 'relation': 'is_a'},
#    {'id': 'GO:0045737', 'relation': 'is_a'},
#    {'id': 'GO:0016538', 'relation': 'part_of'}],
#   'aspect': 'biological_process',
#   'usage': 'Unrestricted',
#   'parent': [{'id': 'GO:0004693', 'relation': 'regulates'},
#    {'id': 'GO:0071900', 'relation': 'is_a'},
#    {'id': 'GO:1904029', 'relation': 'is_a'},
#    {'id': 'GO:0016537', 'relation': 'regulates'}]},
#  'GO:0000080': {'id': 'GO:0000080',
#   'isObsolete': False,
#   'name': 'mitotic G1 phase',
#   'definition': {'text': "The cell cycle 'gap' phase which is the interval between the completion of DNA segregation by mitosis and the beginning of DNA synthesis."},
#   'comment': "Note that this term should not be used for direct annotation. If you are trying to make an annotation to x phase, it is likely that the correct annotation is 'regulation of x/y phase transition' or to a process which occurs during the reported phase (i.e mitotic DNA replication for mitotic S-phase). To capture the phase when a specific location or process is observed, the phase term can be used in an annotation extension (PMID:24885854) applied to a cellular component term (with the relation exists_during) or a biological process term (with the relation happens_during).",
#   'synonyms': [{'name': 'G1 phase of mitotic cell cycle', 'type': 'exact'}],
#   'aspect': 'biological_process',
#   'usage': 'None',
#   'parent': [{'id': 'GO:0051318', 'relation': 'is_a'},
#    {'id': 'GO:0051329', 'relation': 'part_of'}]},
#  'GO:0000082': {'id': 'GO:0000082',
#   'isObsolete': False,
#   'name': 'G1/S transition of mitotic cell cycle',
#   'definition': {'text': 'The mitotic cell cycle transition by which a cell in G1 commits to S phase. The process begins with the build up of G1 cyclin-dependent kinase (G1 CDK), resulting in the activation of transcription of G1 cyclins. The process ends with the positive feedback of the G1 cyclins on the G1 CDK which commits the cell to S phase, in which DNA replication is initiated.'},
#   'children': [{'id': 'GO:0000083', 'relation': 'part_of'},
#    {'id': 'GO:0071930', 'relation': 'part_of'},
#    {'id': 'GO:2000045', 'relation': 'regulates'},
#    {'id': 'GO:0071931', 'relation': 'part_of'},
#    {'id': 'GO:0031571', 'relation': 'negatively_regulates'},
#    {'id': 'GO:1900477', 'relation': 'negatively_regulates'},
#    {'id': 'GO:2000134', 'relation': 'negatively_regulates'},
#    {'id': 'GO:1900087', 'relation': 'positively_regulates'},
#    {'id': 'GO:0031568', 'relation': 'negatively_regulates'}],
#   'aspect': 'biological_process',
#   'usage': 'Unrestricted',
#   'parent': [{'id': 'GO:0000278', 'relation': 'part_of'},
#    {'id': 'GO:0044772', 'relation': 'is_a'},
#    {'id': 'GO:0044843', 'relation': 'is_a'},
#    {'id': 'GO:0007067', 'relation': 'part_of'}]},
#  'GO:0000083': {'id': 'GO:0000083',
#   'isObsolete': False,
#   'name': 'regulation of transcription involved in G1/S transition of mitotic cell cycle',
#   'definition': {'text': 'Any process that regulates transcription such that the target genes are involved in the transition between G1 and S phase of the mitotic cell cycle.'},
#   'children': [{'id': 'GO:0071931', 'relation': 'is_a'},
#    {'id': 'GO:0071930', 'relation': 'is_a'}],
#   'aspect': 'biological_process',
#   'usage': 'Unrestricted',
#   'parent': [{'id': 'GO:0000082', 'relation': 'part_of'},
#    {'id': 'GO:0006355', 'relation': 'is_a'},
#    {'id': 'GO:1903047', 'relation': 'is_a'},
#    {'id': 'GO:0061019', 'relation': 'is_a'},
#    {'id': 'GO:0032583', 'relation': 'is_a'},
#    {'id': 'GO:0045449', 'relation': 'is_a'}]},
#  'GO:0000084': {'id': 'GO:0000084',
#   'isObsolete': False,
#   'name': 'mitotic S phase',
#   'definition': {'text': 'The cell cycle phase, following G1, during which DNA synthesis takes place as part of a mitotic cell cycle.'},
#   'comment': "Note that this term should not be used for direct annotation. If you are trying to make an annotation to x phase, it is likely that the correct annotation is 'regulation of x/y phase transition' or to a process which occurs during the reported phase (i.e mitotic DNA replication for mitotic S-phase). To capture the phase when a specific location or process is observed, the phase term can be used in an annotation extension (PMID:24885854) applied to a cellular component term (with the relation exists_during) or a biological process term (with the relation happens_during).",
#   'synonyms': [{'name': 'S phase of mitotic cell cycle', 'type': 'exact'},
#    {'name': 'S-phase of mitotic cell cycle', 'type': 'exact'}],
#   'aspect': 'biological_process',
#   'usage': 'None',
#   'parent': [{'id': 'GO:0051320', 'relation': 'is_a'},
#    {'id': 'GO:0051329', 'relation': 'part_of'}]},
#  'GO:0000085': {'id': 'GO:0000085',
#   'isObsolete': False,
#   'name': 'mitotic G2 phase',
#   'definition': {'text': "The cell cycle 'gap' phase which is the interval between the completion of DNA synthesis and the beginning of DNA segregation by mitosis."},
#   'comment': "Note that this term should not be used for direct annotation. If you are trying to make an annotation to x phase, it is likely that the correct annotation is 'regulation of x/y phase transition' or to a process which occurs during the reported phase (i.e mitotic DNA replication for mitotic S-phase). To capture the phase when a specific location or process is observed, the phase term can be used in an annotation extension (PMID:24885854) applied to a cellular component term (with the relation exists_during) or a biological process term (with the relation happens_during).",
#   'synonyms': [{'name': 'G2 phase of mitotic cell cycle', 'type': 'exact'}],
#   'aspect': 'biological_process',
#   'usage': 'None',
#   'parent': [{'id': 'GO:0051319', 'relation': 'is_a'},
#    {'id': 'GO:0051329', 'relation': 'part_of'}]},
#  'GO:0000086': {'id': 'GO:0000086',
#   'isObsolete': False,
#   'name': 'G2/M transition of mitotic cell cycle',
#   'definition': {'text': 'The mitotic cell cycle transition by which a cell in G2 commits to M phase. The process begins when the kinase activity of M cyclin/CDK complex reaches a threshold high enough for the cell cycle to proceed. This is accomplished by activating a positive feedback loop that results in the accumulation of unphosphorylated and active M cyclin/CDK complex.'},
#   'synonyms': [{'name': 'mitotic G2/M transition', 'type': 'exact'}],
#   'children': [{'id': 'GO:0031569', 'relation': 'negatively_regulates'},
#    {'id': 'GO:0000117', 'relation': 'part_of'},
#    {'id': 'GO:0031661', 'relation': 'regulates'},
#    {'id': 'GO:0031660', 'relation': 'regulates'},
#    {'id': 'GO:0010389', 'relation': 'regulates'},
#    {'id': 'GO:0090419', 'relation': 'part_of'},
#    {'id': 'GO:0010972', 'relation': 'negatively_regulates'},
#    {'id': 'GO:0010971', 'relation': 'positively_regulates'},
#    {'id': 'GO:0090282', 'relation': 'part_of'}],
#   'aspect': 'biological_process',
#   'usage': 'Unrestricted',
#   'parent': [{'id': 'GO:0000278', 'relation': 'part_of'},
#    {'id': 'GO:0044772', 'relation': 'is_a'},
#    {'id': 'GO:0044839', 'relation': 'is_a'},
#    {'id': 'GO:0007067', 'relation': 'part_of'}]},
#  'GO:0000087': {'id': 'GO:0000087',
#   'isObsolete': False,
#   'name': 'mitotic M phase',
#   'definition': {'text': 'A cell cycle phase during which nuclear division occurs, and which is comprises the phases: prophase, metaphase, anaphase and telophase and occurs as part of a mitotic cell cycle.'},
#   'comment': "Note that this term should not be used for direct annotation. If you are trying to make an annotation to x phase, it is likely that the correct annotation is 'regulation of x/y phase transition' or to a process which occurs during the reported phase (i.e mitotic DNA replication for mitotic S-phase). To capture the phase when a specific location or process is observed, the phase term can be used in an annotation extension (PMID:24885854) applied to a cellular component term (with the relation exists_during) or a biological process term (with the relation happens_during).",
#   'synonyms': [{'name': 'M phase of mitotic cell cycle', 'type': 'exact'},
#    {'name': 'M-phase of mitotic cell cycle', 'type': 'exact'}],
#   'children': [{'id': 'GO:0000089', 'relation': 'part_of'},
# ...
#    'xrefs': [{'dbCode': 'CL', 'dbId': '0000236'},
#     {'dbCode': 'ISBN', 'dbId': '0781735149'}]},
#   'synonyms': [{'name': 'B cell apoptosis', 'type': 'narrow'},
#    {'name': 'B-lymphocyte programmed cell death by apoptosis',
#     'type': 'exact'},
#    {'name': 'B-lymphocyte apoptosis', 'type': 'exact'},
#    {'name': 'B-cell programmed cell death by apoptosis', 'type': 'exact'},
#    {'name': 'B-cell apoptosis', 'type': 'exact'},
#    {'name': 'B lymphocyte programmed cell death by apoptosis',
#     'type': 'exact'},
#    {'name': 'B lymphocyte apoptosis', 'type': 'exact'},
#    {'name': 'B cell programmed cell death by apoptosis', 'type': 'exact'},
#    {'name': 'programmed cell death, B-lymphocytes', 'type': 'exact'},
#    {'name': 'programmed cell death, B-cells', 'type': 'exact'},
#    {'name': 'programmed cell death, B lymphocytes', 'type': 'exact'},
#    {'name': 'programmed cell death, B cells', 'type': 'exact'},
#    {'name': 'programmed cell death of B-lymphocytes by apoptosis',
#     'type': 'exact'},
#    {'name': 'programmed cell death of B-cells by apoptosis', 'type': 'exact'},
#    {'name': 'programmed cell death of B lymphocytes by apoptosis',
#     'type': 'exact'},
#    {'name': 'programmed cell death of B cells by apoptosis', 'type': 'exact'},
#    {'name': 'apoptosis of B-lymphocytes', 'type': 'exact'},
#    {'name': 'apoptosis of B cells', 'type': 'exact'},
#    {'name': 'apoptosis of B lymphocytes', 'type': 'exact'},
#    {'name': 'apoptosis of B-cells', 'type': 'exact'}],
#   'children': [{'id': 'GO:0002516', 'relation': 'is_a'},
#    {'id': 'GO:0002903', 'relation': 'negatively_regulates'},
#    {'id': 'GO:0002902', 'relation': 'regulates'},
#    {'id': 'GO:0071948', 'relation': 'is_a'},
#    {'id': 'GO:0002901', 'relation': 'is_a'},
#    {'id': 'GO:0002904', 'relation': 'positively_regulates'},
#    {'id': 'GO:1990117', 'relation': 'part_of'}],
#   'aspect': 'biological_process',
#   'usage': 'Unrestricted',
#   'parent': [{'id': 'GO:0070227', 'relation': 'is_a'}]},
#  'GO:0001784': {'id': 'GO:0001784',
#   'isObsolete': False,
#   'name': 'phosphotyrosine residue binding',
#   'definition': {'text': 'Interacting selectively and non-covalently with a phosphorylated tyrosine residue within a protein.',
#    'xrefs': [{'dbCode': 'PMID', 'dbId': '14636584'}]},
#   'synonyms': [{'name': 'phosphotyrosine binding', 'type': 'related'}],
#   'aspect': 'molecular_function',
#   'usage': 'Unrestricted',
#   'parent': [{'id': 'GO:0045309', 'relation': 'is_a'}]},
#  'GO:0001785': {'id': 'GO:0001785',
#   'isObsolete': False,
#   'name': 'prostaglandin J receptor activity',
#   'definition': {'text': 'Combining with prostaglandin J (PGJ(2)), a metabolite of prostaglandin D (PGD(2)) to initiate a change in cell activity.',
#    'xrefs': [{'dbCode': 'PMID', 'dbId': '12878180'}]},
#   'synonyms': [{'name': 'PGJ receptor activity', 'type': 'related'},
#    {'name': 'PGJ(2) receptor activity', 'type': 'exact'}],
#   'aspect': 'molecular_function',
#   'usage': 'Unrestricted',
#   'parent': [{'id': 'GO:0004955', 'relation': 'is_a'}]},
#  'GO:0001786': {'id': 'GO:0001786',
#   'isObsolete': False,
#   'name': 'phosphatidylserine binding',
#   'definition': {'text': 'Interacting selectively and non-covalently with phosphatidylserine, a class of glycophospholipids in which a phosphatidyl group is esterified to the hydroxyl group of L-serine.',
#    'xrefs': [{'dbCode': 'ISBN', 'dbId': '0198506732'},
#     {'dbCode': 'PMID', 'dbId': '12000961'}]},
#   'aspect': 'molecular_function',
#   'usage': 'Unrestricted',
#   'parent': [{'id': 'GO:0005543', 'relation': 'is_a'},
#    {'id': 'GO:0072341', 'relation': 'is_a'}]},
#  'GO:0001787': {'id': 'GO:0001787',
#   'isObsolete': False,
#   'name': 'natural killer cell proliferation',
#   'definition': {'text': 'The expansion of a natural killer cell population by cell division.',
#    'xrefs': [{'dbCode': 'ISBN', 'dbId': '0781735149'}]},
#   'synonyms': [{'name': 'NK cell proliferation', 'type': 'exact'}],
#   'children': [{'id': 'GO:0032817', 'relation': 'regulates'},
#    {'id': 'GO:0032818', 'relation': 'negatively_regulates'},
#    {'id': 'GO:0002324', 'relation': 'is_a'},
#    {'id': 'GO:0032819', 'relation': 'positively_regulates'}],
#   'aspect': 'biological_process',
#   'usage': 'Unrestricted',
#   'parent': [{'id': 'GO:0030101', 'relation': 'is_a'},
#    {'id': 'GO:0046651', 'relation': 'is_a'}]},
#  'GO:0001788': {'id': 'GO:0001788',
#   'isObsolete': False,
#   'name': 'antibody-dependent cellular cytotoxicity',
#   'definition': {'text': 'Cytolysis of target cells by natural killer cells, eosinophils, neutrophils, monocytes, or macrophages following engagement of antibodies bound to the target cells by Fc receptors on the effector cells.',
#    'xrefs': [{'dbCode': 'ISBN', 'dbId': '0781735149'},
#     {'dbCode': 'PMID', 'dbId': '11677095'},
#     {'dbCode': 'PMID', 'dbId': '9581795'}]},
#   'synonyms': [{'name': 'type VI hypersensitivity', 'type': 'exact'},
#    {'name': 'antibody dependent cell death', 'type': 'exact'},
#    {'name': 'antibody dependent cell killing', 'type': 'exact'},
#    {'name': 'antibody-dependent cell death', 'type': 'exact'},
#    {'name': 'ADCC', 'type': 'exact'},
#    {'name': 'antibody-dependent cell killing', 'type': 'exact'}],
#   'children': [{'id': 'GO:0001813', 'relation': 'regulates'},
#    {'id': 'GO:0001814', 'relation': 'negatively_regulates'},
#    {'id': 'GO:0001815', 'relation': 'positively_regulates'}],
#   'aspect': 'biological_process',
#   'usage': 'Unrestricted',
#   'parent': [{'id': 'GO:0001794', 'relation': 'is_a'},
#    {'id': 'GO:0001909', 'relation': 'is_a'}]},
#  'GO:0001790': {'id': 'GO:0001790',
#   'isObsolete': False,
#   'name': 'polymeric immunoglobulin binding',
#   'definition': {'text': 'Interacting selectively and non-covalently with a J-chain-containing polymeric immunoglobulin of the IgA or IgM isotypes.',
#    'xrefs': [{'dbCode': 'ISBN', 'dbId': '0781735149'}]},
#   'aspect': 'molecular_function',
#   'usage': 'Unrestricted',
#   'parent': [{'id': 'GO:0019865', 'relation': 'is_a'}]},
#  'GO:0001791': {'id': 'GO:0001791',
#   'isObsolete': False,
#   'name': 'IgM binding',
#   'definition': {'text': 'Interacting selectively and non-covalently with an immunoglobulin of the IgM isotype.',
#    'xrefs': [{'dbCode': 'ISBN', 'dbId': '0781735149'}]},
#   'aspect': 'molecular_function',
#   'usage': 'Unrestricted',
#   'parent': [{'id': 'GO:0019865', 'relation': 'is_a'}]},
#  'GO:0001792': {'id': 'GO:0001792',
#   'isObsolete': False,
#   'name': 'polymeric immunoglobulin receptor activity',
#   'definition': {'text': 'Combining with a J-chain-containing polymeric immunoglobulin of the IgA or IgM isotypes via the Fc region, and transmitting the signal from one side of the membrane to the other to initiate a change in cell activity.',
#    'xrefs': [{'dbCode': 'ISBN', 'dbId': '0781735149'}]},
#   'aspect': 'molecular_function',
#   'usage': 'Unrestricted',
#   'parent': [{'id': 'GO:0019763', 'relation': 'is_a'},
#    {'id': 'GO:0016489', 'relation': 'is_a'}]},
#  'GO:0001793': {'id': 'GO:0001793',
#   'isObsolete': False,
#   'name': 'IgM receptor activity',
#   'definition': {'text': 'Combining with an immunoglobulin of the IgM isotype via the Fc region, and transmitting the signal from one side of the membrane to the other to initiate a change in cell activity.',
#    'xrefs': [{'dbCode': 'ISBN', 'dbId': '0781735149'}]},
#   'children': [{'id': 'GO:0002173', 'relation': 'is_a'},
#    {'id': 'GO:0002172', 'relation': 'is_a'}],
#   'aspect': 'molecular_function',
#   'usage': 'Unrestricted',
#   'parent': [{'id': 'GO:0019763', 'relation': 'is_a'},
#    {'id': 'GO:0016489', 'relation': 'is_a'}]},
#  'GO:0001794': {'id': 'GO:0001794',
#   'isObsolete': False,
#   'name': 'type IIa hypersensitivity',
#   'definition': {'text': 'An inflammatory response resulting in cell death mediated by activation of the classical complement pathway or induction of effector cell phagocytosis or cytolysis mechanisms via complement or Fc receptors following the binding of antibodies to cell surface antigens on a target cell.',
#    'xrefs': [{'dbCode': 'ISBN', 'dbId': '0781735149'}]},
#   'comment': 'Note that some type IIb hypersensitivity responses (GO:0001795) are referred to simply as type II hypersensitivity in the earlier literature, but are mechanistically distinct from type IIa hypersensitivity.',
#   'children': [{'id': 'GO:0001798', 'relation': 'positively_regulates'},
#    {'id': 'GO:0001796', 'relation': 'regulates'},
#    {'id': 'GO:0001788', 'relation': 'is_a'},
#    {'id': 'GO:0001797', 'relation': 'negatively_regulates'}],
#   'aspect': 'biological_process',
#   'usage': 'Unrestricted',
#   'parent': [{'id': 'GO:0002445', 'relation': 'is_a'}]},
#  'GO:0001795': {'id': 'GO:0001795',
#   'isObsolete': False,
#   'name': 'type IIb hypersensitivity',
#   'definition': {'text': 'An inflammatory response resulting in cell death or dysfunction mediated by the direct binding of antibody to cellular receptors.',
#    'xrefs': [{'dbCode': 'ISBN', 'dbId': '0781735149'}]},
#   'comment': 'Note that some type IIa hypersensitivity response (GO:0001794) are referred to simply as type II hypersensitivity in the earlier literature, but are mechanistically distinct from type IIb hypersensitivity.',
#   'synonyms': [{'name': 'type V hypersensitivity', 'type': 'exact'}],
#   'children': [{'id': 'GO:0001800', 'relation': 'negatively_regulates'},
#    {'id': 'GO:0001799', 'relation': 'regulates'},
#    {'id': 'GO:0001801', 'relation': 'positively_regulates'}],
#   'aspect': 'biological_process',
#   'usage': 'Unrestricted',
#   'parent': [{'id': 'GO:0002445', 'relation': 'is_a'}]},
#  'GO:0001796': {'id': 'GO:0001796',
#   'isObsolete': False,
#   'name': 'regulation of type IIa hypersensitivity',
#   'definition': {'text': 'Any process that modulates the frequency, rate, or extent of type IIa hypersensitivity, a type of inflammatory response.',
#    'xrefs': [{'dbCode': 'ISBN', 'dbId': '0781735149'}]},
#   'children': [{'id': 'GO:0001798', 'relation': 'is_a'},
#    {'id': 'GO:0001813', 'relation': 'is_a'},
#    {'id': 'GO:0001797', 'relation': 'is_a'}],
#   'aspect': 'biological_process',
#   'usage': 'Unrestricted',
#   'parent': [{'id': 'GO:0001794', 'relation': 'regulates'},
#    {'id': 'GO:0002892', 'relation': 'is_a'}]},
#  'GO:0001797': {'id': 'GO:0001797',
#   'isObsolete': False,
#   'name': 'negative regulation of type IIa hypersensitivity',
#   'definition': {'text': 'Any process that stops, prevents, or reduces the rate of type IIa hypersensitivity, a type of inflammatory response.',
#    'xrefs': [{'dbCode': 'ISBN', 'dbId': '0781735149'}]},
#   'synonyms': [{'name': 'inhibition of type IIa hypersensitivity',
#     'type': 'narrow'},
#    {'name': 'downregulation of type IIa hypersensitivity', 'type': 'exact'},
#    {'name': 'down regulation of type IIa hypersensitivity', 'type': 'exact'},
#    {'name': 'down-regulation of type IIa hypersensitivity', 'type': 'exact'}],
#   'children': [{'id': 'GO:0001814', 'relation': 'is_a'}],
#   'aspect': 'biological_process',
#   'usage': 'Unrestricted',
#   'parent': [{'id': 'GO:0001794', 'relation': 'negatively_regulates'},
#    {'id': 'GO:0001796', 'relation': 'is_a'},
#    {'id': 'GO:0002893', 'relation': 'is_a'}]},
#  'GO:0001798': {'id': 'GO:0001798',
#   'isObsolete': False,
#   'name': 'positive regulation of type IIa hypersensitivity',
#   'definition': {'text': 'Any process that activates or increases the frequency, rate or extent of type IIa hypersensitivity, a type of inflammatory response.',
#    'xrefs': [{'dbCode': 'ISBN', 'dbId': '0781735149'}]},
#   'synonyms': [{'name': 'up regulation of type IIa hypersensitivity',
#     'type': 'exact'},
#    {'name': 'up-regulation of type IIa hypersensitivity', 'type': 'exact'},
#    {'name': 'upregulation of type IIa hypersensitivity', 'type': 'exact'},
#    {'name': 'activation of type IIa hypersensitivity', 'type': 'narrow'},
#    {'name': 'stimulation of type IIa hypersensitivity', 'type': 'narrow'}],
#   'children': [{'id': 'GO:0001815', 'relation': 'is_a'}],
#   'aspect': 'biological_process',
#   'usage': 'Unrestricted',
#   'parent': [{'id': 'GO:0001794', 'relation': 'positively_regulates'},
#    {'id': 'GO:0001796', 'relation': 'is_a'},
#    {'id': 'GO:0002894', 'relation': 'is_a'}]},
#  'GO:0001799': {'id': 'GO:0001799',
#   'isObsolete': False,
#   'name': 'regulation of type IIb hypersensitivity',
#   'definition': {'text': 'Any process that modulates the frequency, rate, or extent of type IIb hypersensitivity, a type of inflammatory response.',
#    'xrefs': [{'dbCode': 'ISBN', 'dbId': '0781735149'}]},
#   'children': [{'id': 'GO:0001800', 'relation': 'is_a'},
#    {'id': 'GO:0001801', 'relation': 'is_a'}],
#   'aspect': 'biological_process',
#   'usage': 'Unrestricted',
#   'parent': [{'id': 'GO:0001795', 'relation': 'regulates'},
#    {'id': 'GO:0002892', 'relation': 'is_a'}]},
#  'GO:0001800': {'id': 'GO:0001800',
#   'isObsolete': False,
#   'name': 'negative regulation of type IIb hypersensitivity',
#   'definition': {'text': 'Any process that stops, prevents, or reduces the rate of type IIb hypersensitivity, a type of inflammatory response.',
#    'xrefs': [{'dbCode': 'ISBN', 'dbId': '0781735149'}]},
#   'synonyms': [{'name': 'inhibition of type IIb hypersensitivity',
#     'type': 'narrow'},
#    {'name': 'down-regulation of type IIb hypersensitivity', 'type': 'exact'},
#    {'name': 'downregulation of type IIb hypersensitivity', 'type': 'exact'},
#    {'name': 'down regulation of type IIb hypersensitivity', 'type': 'exact'}],
#   'aspect': 'biological_process',
#   'usage': 'Unrestricted',
#   'parent': [{'id': 'GO:0001795', 'relation': 'negatively_regulates'},
#    {'id': 'GO:0001799', 'relation': 'is_a'},
#    {'id': 'GO:0002893', 'relation': 'is_a'}]},
#  'GO:0001801': {'id': 'GO:0001801',
#   'isObsolete': False,
#   'name': 'positive regulation of type IIb hypersensitivity',
#   'definition': {'text': 'Any process that activates or increases the frequency, rate or extent of type IIb hypersensitivity, a type of inflammatory response.',
#    'xrefs': [{'dbCode': 'ISBN', 'dbId': '0781735149'}]},
#   'synonyms': [{'name': 'stimulation of type IIb hypersensitivity',
#     'type': 'narrow'},
#    {'name': 'activation of type IIb hypersensitivity', 'type': 'narrow'},
#    {'name': 'up regulation of type IIb hypersensitivity', 'type': 'exact'},
#    {'name': 'up-regulation of type IIb hypersensitivity', 'type': 'exact'},
#    {'name': 'upregulation of type IIb hypersensitivity', 'type': 'exact'}],
#   'aspect': 'biological_process',
#   'usage': 'Unrestricted',
#   'parent': [{'id': 'GO:0001795', 'relation': 'positively_regulates'},
#    {'id': 'GO:0001799', 'relation': 'is_a'},
#    {'id': 'GO:0002894', 'relation': 'is_a'}]},
#  'GO:0001802': {'id': 'GO:0001802',
#   'isObsolete': False,
#   'name': 'type III hypersensitivity',
#   'definition': {'text': 'An inflammatory response resulting from recognition of immune complexes via complement or Fc receptors on effector cells leading to activation of neutrophils and other leukocytes and damage to bystander tissue.',
#    'xrefs': [{'dbCode': 'ISBN', 'dbId': '0781735149'}]},
#   'comment': 'Note that the Arthus reaction is an example of type III hypersensitivity.',
#   'children': [{'id': 'GO:0001804', 'relation': 'negatively_regulates'},
#    {'id': 'GO:0001805', 'relation': 'positively_regulates'},
#    {'id': 'GO:0001803', 'relation': 'regulates'}],
#   'aspect': 'biological_process',
#   'usage': 'Unrestricted',
#   'parent': [{'id': 'GO:0002444', 'relation': 'is_a'},
#    {'id': 'GO:0002524', 'relation': 'is_a'},
#    {'id': 'GO:0016064', 'relation': 'is_a'}]},
#  'GO:0001803': {'id': 'GO:0001803',
#   'isObsolete': False,
#   'name': 'regulation of type III hypersensitivity',
#   'definition': {'text': 'Any process that modulates the frequency, rate, or extent of type III hypersensitivity, a type of inflammatory response.',
#    'xrefs': [{'dbCode': 'ISBN', 'dbId': '0781735149'}]},
#   'children': [{'id': 'GO:0001804', 'relation': 'is_a'},
#    {'id': 'GO:0001805', 'relation': 'is_a'}],
#   'aspect': 'biological_process',
#   'usage': 'Unrestricted',
#   'parent': [{'id': 'GO:0001802', 'relation': 'regulates'},
#    {'id': 'GO:0002883', 'relation': 'is_a'},
#    {'id': 'GO:0002886', 'relation': 'is_a'},
#    {'id': 'GO:0002889', 'relation': 'is_a'}]},
#  ...}

# %%
#import owlready2

import types
from owlready2 import *
onto = get_ontology("http://test.org/onto.owl")
# Out:
# * Owlready2 * Warning: optimized Cython parser module 'owlready2_optimized' is not available, defaulting to slower Python implementation

# %%
#classmaker function to make FTC classes

def classmaker(term, parentclass):
                classnameA = 'GOA' + str(term)
                classnameP = 'GOP' + str(term)
                with onto:
                    classname = types.new_class(classnameA, (parentclass,))
                    classname = types.new_class(classnameP, (parentclass,))
                return 0

# %%
#define core classes

with onto:
    class therapeutic_agent(Thing):
        namespace = onto
    class biological_process(Thing):
        namespace = onto
    class molecular_function(Thing):
        namespace = onto
    class drug(Thing):
        namespace = onto

# %%
#recursive classmakers


def recursive_classmaker_down(term, parent):
    parent = getattr(onto, parent)
    with onto:
        nc = types.new_class(term, (parent,))
    parent = getattr(onto, term)
    for item in nary[term]['children']:
        recursive_classmaker_down(item['id'][3:], parent)
    return 0



def recursive_classmaker_up(term, parent):
    if parent not in [str(s) for s in list(onto.classes())]:
        for item in nary[('GO:' + term)]['parent']:
            recursive_classmaker_up(parent, item['id'][3:])
            
    if nary[('GO:' + term)]['parent'] == []:
        with onto:
            nc = types.new_class(parent, (biological_process,))
        #recursive_classmaker_down(term, parent)
    return 0

# %%
#Using classmaker to make FTC classes

for key, value in kilnary.items():
    if value['aspect'] == 'biological_process':
        for item in value['children']:
            if item['relation'] == 'positively_regulates' or 'negatively_regulates' or 'regulates':
                recursive_classmaker_up(str(item['id'][3:]), value['id'][3:])
            if item['relation'] == 'capable of' or 'part_of' or 'capable_of_part_of' or 'has_part':
                recursive_classmaker_up(str(item['id'][3:]), value['id'][3:])
            
            
            
#             if item['relation'] == 'negatively_regulates':
#                 recursive_classmaker_up(str(item['id'][3:]), value['id'][3:])
#             if item['relation'] == 'regulates':
#                 recursive_classmaker_up(str(item['id'][3:]), value['id'][3:])
#     if value['aspect'] == 'molecular_function':
#         for item in value['children']:
#             if item['relation'] == 'positively_regulates':
#                 classmaker(str(item['id'][3:]), therapeutic_agent)
#             if item['relation'] == 'negatively_regulates':
#                 classmaker(str(item['id'][3:]), therapeutic_agent)
#             if item['relation'] == 'regulates':
#                 classmaker(str(item['id'][3:]), therapeutic_agent)

# %%
onto.save(file = "testowl2", format = "rdfxml")

# %%
list(onto.classes())
# Out:
# [onto.therapeutic_agent,
#  onto.biological_process,
#  onto.molecular_function,
#  onto.drug,
#  onto.0008150,
#  onto.0007582,
#  onto.0000004,
#  onto.0044699,
#  onto.0008152,
#  onto.0044236,
#  onto.0044710,
#  onto.0071704,
#  onto.0009987,
#  onto.0050875,
#  onto.0044763,
#  onto.0008151,
#  onto.0043170,
#  onto.0044237,
#  onto.0043283,
#  onto.0044259,
#  onto.0006807,
#  onto.0006725,
#  onto.0034641,
#  onto.0044238,
#  onto.0046483,
#  onto.1901360,
#  onto.0006139,
#  onto.0055134,
#  onto.0044260,
#  onto.0090304,
#  onto.0034960,
#  onto.0050896,
#  onto.0051869,
#  onto.0006950,
#  onto.0051716,
#  onto.0033554,
#  onto.0006259,
#  onto.0006974,
#  onto.0055132,
#  onto.0034984,
#  onto.0065007,
#  onto.0050789,
#  onto.0050791,
#  onto.0019222,
#  onto.0050794,
#  onto.0044246,
#  onto.0051244,
#  onto.0031323,
#  onto.0051171,
#  onto.0080090,
#  onto.0019219,
#  onto.0060255,
#  onto.0048583,
#  onto.0080134,
#  onto.0080135,
#  onto.0006281,
#  onto.0051052,
#  onto.2001020,
#  onto.0048519,
#  onto.0043118,
#  onto.0009892,
#  onto.0044252,
#  onto.0048523,
#  onto.0051243,
#  onto.0031324,
#  onto.0051172,
#  onto.0010605,
#  onto.0045934,
#  onto.0048585,
#  onto.0048518,
#  onto.0043119,
#  onto.0009893,
#  onto.0044253,
#  onto.0048522,
#  onto.0051242,
#  onto.0031325,
#  onto.0051173,
#  onto.0010604,
#  onto.0045935,
#  onto.0048584,
#  onto.0071840,
#  onto.0071841,
#  onto.0016043,
#  onto.0044235,
#  onto.0071842,
#  onto.0006996,
#  onto.1902589,
#  onto.0007049,
#  onto.0007059,
#  onto.0022402,
#  onto.0051276,
#  onto.0098813,
#  onto.0007001,
#  onto.0051277,
#  onto.0048285,
#  onto.0000278,
#  onto.0007067,
#  onto.0000280,
#  onto.1903047,
#  onto.0007010,
#  onto.0007017,
#  onto.0000226,
#  onto.0000819,
#  onto.0140014,
#  onto.0007051,
#  onto.1902850,
#  onto.0043146,
#  onto.0000070,
#  onto.0007052,
#  onto.0051231,
#  onto.0016359,
#  onto.0030472,
#  onto.0000071,
#  onto.0043148,
#  onto.0051726,
#  onto.0000074,
#  onto.0051128,
#  onto.0033043,
#  onto.0032886,
#  onto.0051493,
#  onto.0010564,
#  onto.0070507,
#  onto.0007346,
#  onto.0051783,
#  onto.0033044,
#  onto.0051983,
#  onto.0090224,
#  onto.0007088,
#  onto.0033045,
#  onto.0000022,
#  onto.0032887,
#  onto.0033047,
#  onto.0060236,
#  onto.0045786,
#  onto.0051129,
#  onto.0010639,
#  onto.0010948,
#  onto.0051985,
#  onto.2001251,
#  onto.0045930,
#  onto.0051784,
#  onto.0033046,
#  onto.0045839,
#  onto.0045787,
#  onto.0051130,
#  onto.0010638,
#  onto.0045931,
#  onto.0051785,
#  onto.0090068,
#  onto.0045840,
#  onto.0051984,
#  onto.2001252,
#  onto.0051495,
#  onto.0044085,
#  onto.0071843,
#  onto.0022607,
#  onto.0071844,
#  onto.0009056,
#  onto.0044712,
#  onto.0044243,
#  onto.0044248,
#  onto.0061919,
#  onto.0006914,
#  onto.0016238,
#  onto.0007033,
#  onto.0016236,
#  onto.0044086,
#  onto.0034262,
#  onto.0009894,
#  onto.0031329,
#  onto.0009896,
#  onto.0010506,
#  onto.0031331,
#  onto.0044087,
#  onto.0070925,
#  onto.1905037,
#  onto.0009895,
#  onto.0031330,
#  onto.0051179,
#  onto.1902578,
#  onto.0033036,
#  onto.0051641,
#  onto.1902580,
#  onto.0008104,
#  onto.0051640,
#  onto.0008105,
#  onto.0022613,
#  onto.0051234,
#  onto.0050657,
#  onto.0051236,
#  onto.0006913,
#  onto.0000063,
#  onto.0050658,
#  onto.0051168,
#  onto.0015031,
#  onto.0034613,
#  onto.0046907,
#  onto.0015831,
#  onto.0016249,
#  onto.1902582,
#  onto.0006886,
#  onto.0032779,
#  onto.0006405,
#  onto.0006611,
#  onto.0031503,
#  onto.0071166,
#  onto.0097349,
#  onto.0071426,
#  onto.0015931,
#  onto.0006403,
#  onto.0051169,
#  onto.0015833,
#  onto.0045184,
#  onto.0070727,
#  onto.0006810,
#  onto.0015457,
#  onto.0044765,
#  onto.0015460,
#  onto.0071702,
#  onto.0071705,
#  onto.0042886,
#  onto.0033750,
#  onto.0042254,
#  onto.0051656,
#  onto.0071428,
#  onto.0033753,
#  onto.0007046,
#  onto.0032879,
#  onto.0051049,
#  onto.0060341,
#  onto.0032386,
#  onto.0051051,
#  onto.0032387,
#  onto.0046822,
#  onto.0032880,
#  onto.0070201,
#  onto.0090087,
#  onto.0051223,
#  onto.1903827,
#  onto.0033157,
#  onto.0051235,
#  onto.0045185,
#  onto.0051651,
#  onto.0033365,
#  onto.0032507,
#  onto.0034504,
#  onto.0072595,
#  onto.0044744,
#  onto.1904950,
#  onto.0051224,
#  onto.1903828,
#  onto.0065008,
#  onto.0046823,
#  onto.0046825,
#  onto.0051457,
#  onto.0090317,
#  onto.0032239,
#  onto.0032240,
#  onto.0046831,
#  onto.0090069,
#  onto.2000197,
#  onto.0000054,
#  onto.0051050,
#  onto.0032388,
#  onto.1904951,
#  onto.0051222,
#  onto.1903829,
#  onto.0046824,
#  onto.0090316,
#  onto.0032241,
#  onto.0044089,
#  onto.0051225,
#  onto.0051227,
#  onto.0051226,
#  onto.0090307,
#  onto.0031023,
#  onto.0051300,
#  onto.0051426,
#  onto.1902115,
#  onto.0090169,
#  onto.0061804,
#  onto.0110100,
#  onto.1905047,
#  onto.0032888,
#  onto.1901673]
